# %% [markdown]
# <h1>Splat Space membership stats</h1>

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 15)
pd.set_option('display.width', 400)
pd.set_option('display.mpl_style', 'default')
rcParams['figure.figsize'] = (14, 7)
import matplotlib
font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
member_data = pd.read_csv("./membership.csv", index_col='date', parse_dates=True)

# %%
member_data[:15]
# Out:
#           date  members  dues
# 0   2011-01-01       22  1065
# 1   2011-02-01       25  1110
# 2   2011-03-01       28  1195
# 3   2011-04-01       24  1195
# 4   2011-05-01       24  1190
# 5   2011-06-01       27  1280
# 6   2011-07-01       26  1245
# 7   2011-08-01       26  1195
# 8   2011-09-01       24  1125
# 9   2011-10-01       24  1155
# 10  2011-11-01       23  1060
# 11  2011-12-01       23  1060
# 12  2012-01-01       21   990
# 13  2012-02-01       22  1085
# 14  2012-03-01       22  1070

# %%
member_data[['members', 'dues']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10a194790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10a41fe50>], dtype=object)

# %%
member_data.median()
# Out:
# members      28.0
# dues       1302.5
# dtype: float64

# %%
member_data.max()
# Out:
# date       2014-12
# members         43
# dues          1710
# dtype: object
